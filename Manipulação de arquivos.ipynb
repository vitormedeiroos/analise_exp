# %% [markdown]
# # Manipulação de arquivos

# %%
with open('/content/frase1.txt', 'r') as tex: # r de read, nao necessita
  for linha in tex:
    print(linha)
# Out:
# Olá
#
# Estou aprendendo
#
# a linguagem Python
#
# E estou gostando muito

# %%
with open('/content/frase1.txt') as tex:
  r = tex.readlines()

# %%
r
# Out:
# ['Olá\n',
#  'Estou aprendendo \n',
#  'a linguagem Python\n',
#  'E estou gostando muito']

# %%
with open('texto2.txt', 'w') as texto:#criar 'w' de write
  texto.write('Olá a todos')

# %%
with open('texto2.txt', 'r') as tex:
  for linha in tex:
    print(linha)
# Out:
# Olá a todos

# %% [markdown]
# # Exercício:

# %%
alunos = {'Pedro': 8.0, 'Maria': 10.0,   'Amilton':   7.5}
alunos
# Out:
# {'Pedro': 8.0, 'Maria': 10.0, 'Amilton': 7.5}

# %%
with open( 'texto.txt', 'w') as text:
  texto.write(alunos)
