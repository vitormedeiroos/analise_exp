# %% [markdown]
# <a href="https://colab.research.google.com/github/vitormedeiroos/analise_exp/blob/main/man_dfs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Series - valores que são lastreados à uma ordem...

# %%
series = pd.Series([7,4,5,np.nan,6,8])

# %%
series
# Out:
# 0    7.0
# 1    4.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
datas = pd.date_range('20180122', periods = 6)

# %%
datas
# Out:
# DatetimeIndex(['2018-01-22', '2018-01-23', '2018-01-24', '2018-01-25',
#                '2018-01-26', '2018-01-27'],
#               dtype='datetime64[ns]', freq='D')

# %%
help(pd.date_range)
# Out:
# Help on function date_range in module pandas.core.indexes.datetimes:
#
# date_range(start=None, end=None, periods=None, freq=None, tz=None, normalize: 'bool' = False, name: 'Hashable' = None, closed: "Literal['left', 'right'] | None | lib.NoDefault" = <no_default>, inclusive: 'IntervalClosedType | None' = None, **kwargs) -> 'DatetimeIndex'
#     Return a fixed frequency DatetimeIndex.
#
#     Returns the range of equally spaced time points (where the difference between any
#     two adjacent points is specified by the given frequency) such that they all
#     satisfy `start <[=] x <[=] end`, where the first one and the last one are, resp.,
#     the first and last time points in that range that fall on the boundary of ``freq``
#     (if given as a frequency string) or that are valid for ``freq`` (if given as a
#     :class:`pandas.tseries.offsets.DateOffset`). (If exactly one of ``start``,
#     ``end``, or ``freq`` is *not* specified, this missing parameter can be computed
# ...

# %%
datas_mes = pd.date_range('20180201', periods= 6, freq='M')#m - mes , d = dia

# %%
datas_mes
# Out:
# DatetimeIndex(['2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31',
#                '2018-06-30', '2018-07-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
df = pd.DataFrame(np.random.randn(6,4), index = datas, columns = list("ABCD"))# = ['A','B','C','D']

# %%
np.random.randn(6,4)
# Out:
# array([[ 0.37205573,  1.07713139,  0.46941127,  2.30080427],
#        [-0.55951775, -0.20719524,  0.60640952, -0.07831291],
#        [-0.45174   , -0.729453  ,  1.5660253 , -0.08176168],
#        [-1.8829806 ,  0.25792185,  1.81863893,  1.56422628],
#        [ 0.54760022,  0.90978012, -0.2570708 ,  0.0602921 ],
#        [-0.82327487,  0.04963353,  1.28479907,  0.32696664]])

# %%
list("ABCD")
# Out:
# ['A', 'B', 'C', 'D']

# %%
df
# Out:
#                    A         B         C         D
# 2018-01-22 -1.468741  1.713237 -1.080897  1.511838
# 2018-01-23 -1.008851 -1.648791 -0.605303  1.725860
# 2018-01-24  0.017970 -0.078319  1.786571  0.020808
# 2018-01-25 -0.070626  1.828000 -0.808871  0.673684
# 2018-01-26 -0.830257 -0.324831 -0.316749  0.810502
# 2018-01-27 -0.253442 -1.869009 -0.742705  0.861888

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.index
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-12',
#                '2019-01-13', '2019-01-14', '2019-01-15', '2019-01-16',
#                '2019-01-17', '2019-01-18', '2019-01-19', '2019-01-20',
#                '2019-01-21', '2019-01-22', '2019-01-23', '2019-01-24',
#                '2019-01-25', '2019-01-26', '2019-01-27', '2019-01-28',
#                '2019-01-29', '2019-01-30', '2019-01-31', '2019-02-01',
#                '2019-02-02', '2019-02-03', '2019-02-04', '2019-02-05',
#                '2019-02-06', '2019-02-07', '2019-02-08', '2019-02-09',
#                '2019-02-10', '2019-02-11', '2019-02-12', '2019-02-13',
#                '2019-02-14', '2019-02-15', '2019-02-16', '2019-02-17',
#                '2019-02-18', '2019-02-19', '2019-02-20', '2019-02-21',
# ...

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'Produto', 'NovoProduto', 'ProdutoAB'], dtype='object')

# %%
colunas = df.columns

# %%
#caso queira apenas os valores numéricos
df_valores = df.to_numpy()

# %%
df_valores.T
# Out:
# array([[-1.96161011e+00,  4.67175552e-01, -1.09186428e+00,
#          3.27385990e+00, -1.11844122e+00,  1.46986903e+00,
#          6.51666079e-01,  3.76369736e-01,  3.27923562e-01,
#          1.50823768e+00, -1.38527913e+00, -6.63850664e-01,
#         -5.92264562e-01,  1.01847605e+00,  4.04321019e-01,
#         -5.96392374e-01,  2.83591866e-01,  1.57775176e+00,
#          3.77168925e-01,  1.39185333e-01,  2.89229915e-01,
#          1.87735192e-01, -7.54720251e-01,  5.52486970e-01,
#          6.68835766e-01, -8.05999675e-01,  9.45367505e-02,
#          4.01375986e-01, -7.02072627e-02, -4.76152501e-01,
#          6.81603969e-01, -6.64649715e-01,  3.56106265e-01,
#          9.17618105e-01, -7.72269730e-01,  4.30133321e-01,
#         -2.33575646e-01, -4.75683172e-01,  7.88711221e-01,
#          3.40235315e-01, -1.32493971e+00,  4.19295469e-01,
#          8.66409607e-01, -8.41069916e-01,  5.73057385e-02,
#         -1.21817050e+00, -1.29378084e+00, -8.56338238e-01,
# ...

# %%
df2 = pd.DataFrame({'A': 7,
                    'B':pd.Timestamp('20190101'),
                    'C':pd.Series(1, index=list(range(4)), dtype= 'float32'),
                    'D': pd.Categorical(["train", 'train', 'test', 'train']),
                    'F':'Python'})

# %%
df2.dtypes
# Out:
# A             int64
# B    datetime64[ns]
# C           float32
# D          category
# F            object
# dtype: object

# %%
df2
# Out:
#    A          B    C      D       F
# 0  7 2019-01-01  1.0  train  Python
# 1  7 2019-01-01  1.0  train  Python
# 2  7 2019-01-01  1.0   test  Python
# 3  7 2019-01-01  1.0  train  Python

# %% [markdown]
# # Adicionar novas colunas

# %%
datas = pd.date_range('20190101', periods=60, freq='D')
df = pd.DataFrame(np.random.randn(60,5), index=datas, columns = list('ABCDE'))

# %%
df.shape
# Out:
# (60, 5)

# %%
df.head(2)
# Out:
#                    A         B         C         D         E
# 2019-01-01 -1.961610 -0.494730  1.506442 -0.664450  0.436456
# 2019-01-02  0.467176 -1.145679 -0.394442 -0.467427 -1.250221

# %%
#adicionando novas colunas
df['Produto'] = 1

# %%
#renomear coluna
df['NovoProduto'] = df['Produto']

# Remover a coluna antiga "Produto"
#df = df.drop('Produto', axis=1)

# %%
df.head(4)
# Out:
#                    A         B         C         D         E  Produto  \
# 2019-01-01 -1.961610 -0.494730  1.506442 -0.664450  0.436456        1
# 2019-01-02  0.467176 -1.145679 -0.394442 -0.467427 -1.250221        1
# 2019-01-03 -1.091864 -0.751857 -1.645265 -0.293556 -0.927351        1
# 2019-01-04  3.273860 -0.856953  0.179873 -1.083920 -1.341776        1
#
#             NovoProduto
# 2019-01-01            1
# 2019-01-02            1
# 2019-01-03            1
# 2019-01-04            1

# %%
#fazendo operaçoes entre colunas
df['ProdutoAB'] = df['A'] * df['B']

# %%
df.head(5)
# Out:
#                    A         B         C         D         E  Produto  \
# 2019-01-01 -1.961610 -0.494730  1.506442 -0.664450  0.436456        1
# 2019-01-02  0.467176 -1.145679 -0.394442 -0.467427 -1.250221        1
# 2019-01-03 -1.091864 -0.751857 -1.645265 -0.293556 -0.927351        1
# 2019-01-04  3.273860 -0.856953  0.179873 -1.083920 -1.341776        1
# 2019-01-05 -1.118441  0.747203 -0.464990  1.690957 -0.106812        1
#
#             NovoProduto  ProdutoAB
# 2019-01-01            1   0.970467
# 2019-01-02            1  -0.535233
# 2019-01-03            1   0.820926
# 2019-01-04            1  -2.805543
# 2019-01-05            1  -0.835702

# %%
df['D'] = 88

# %%
desafio = pd.DataFrame({'A': 2,
                    'B':pd.Timestamp('20190101'),
                    'C':pd.Series(1, index=list(range(4)), dtype= 'float32'),
                    'D': pd.Categorical(["train", 'train', 'test', 'train']),
                    'F':'Python'})#2 ; 4; 3; 6; 10;1; 2; 2; 4 e 6
