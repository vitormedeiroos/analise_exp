# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('20200101',periods=6)
df = pd.DataFrame(np.random.randn(6,4), index=datas, columns=['Var_A','Var_B','Var_C','Var_D'])

# %%
#Inverter colunas para linhas (Dataframe transposta = T)
df_transposta  = df.T

# %%
df_transposta
# Out:
#        2020-01-01  2020-01-02  2020-01-03  2020-01-04  2020-01-05  2020-01-06
# Var_A   -0.404020    0.457410    2.626613    0.725015    0.782726    0.258973
# Var_B   -1.138129    2.312793    1.790144    0.836256   -0.562257    1.227516
# Var_C   -0.730409   -0.236918    0.980187   -0.136849    0.958074   -0.163957
# Var_D   -0.301292    0.835263    0.614346    1.897535   -0.788199   -0.547404

# %%
df_transposta.shape
# Out:
# (4, 6)

# %%
df.shape
# Out:
# (6, 4)

# %%
#caso queira extrair somente os valores
v = df.values

# %%
#posso reorganizar em um anoa  estrutura de acordo com o tamanho do meu dataframe
v.reshape((2,12))
# Out:
# array([[-0.40402035, -1.13812918, -0.73040929, -0.3012923 ,  0.45741039,
#          2.31279347, -0.23691799,  0.83526335,  2.62661331,  1.79014447,
#          0.98018656,  0.61434551],
#        [ 0.72501535,  0.83625609, -0.13684944,  1.89753513,  0.78272596,
#         -0.56225732,  0.95807442, -0.78819876,  0.25897272,  1.22751565,
#         -0.16395664, -0.54740379]])
